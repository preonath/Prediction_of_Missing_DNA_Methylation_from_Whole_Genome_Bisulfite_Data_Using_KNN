# %%
# !pip install pyranges
# Out:
# Collecting pyranges
#   Downloading https://files.pythonhosted.org/packages/5a/c9/7e7fdfb336c024f7331dd999da522008ea5c866173e4b4a2e46d9fdc16c3/pyranges-0.0.79.tar.gz (675kB)
#      |████████████████████████████████| 675kB 2.6MB/s
# Requirement already satisfied: cython in /usr/local/lib/python3.6/dist-packages (from pyranges) (0.29.20)
# Requirement already satisfied: pandas in /usr/local/lib/python3.6/dist-packages (from pyranges) (1.0.5)
# Collecting ncls>=0.0.50
#   Downloading https://files.pythonhosted.org/packages/63/77/cee81c97b49c5379245c62364eabb513e5fe18bbfdaa0980874c478e45f8/ncls-0.0.53.tar.gz (463kB)
#      |████████████████████████████████| 471kB 6.9MB/s
# Requirement already satisfied: tabulate in /usr/local/lib/python3.6/dist-packages (from pyranges) (0.8.7)
# Collecting sorted_nearest>=0.0.30
#   Downloading https://files.pythonhosted.org/packages/e7/6e/29a168c3973c54e7de0a98d1680db2c75282b7adbdab7f7562d9395c3b8b/sorted_nearest-0.0.31.tar.gz (1.1MB)
#      |████████████████████████████████| 1.1MB 8.6MB/s
# Collecting pyrle
#   Downloading https://files.pythonhosted.org/packages/9a/5f/6efabd8509cb3c2041e86a4b0b483d3805b6055480c8b19bae053a2edcee/pyrle-0.0.31.tar.gz (346kB)
#      |████████████████████████████████| 348kB 16.2MB/s
# Requirement already satisfied: natsort in /usr/local/lib/python3.6/dist-packages (from pyranges) (5.5.0)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.6/dist-packages (from pandas->pyranges) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas->pyranges) (2018.9)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.6/dist-packages (from pandas->pyranges) (1.18.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil>=2.6.1->pandas->pyranges) (1.12.0)
# Building wheels for collected packages: pyranges, ncls, sorted-nearest, pyrle
#   Building wheel for pyranges (setup.py) ... done
#   Created wheel for pyranges: filename=pyranges-0.0.79-cp36-none-any.whl size=686010 sha256=700518d5c2f083bd2351c49170afce1f38ac073e79a394dc3824ab8b567b53f0
#   Stored in directory: /root/.cache/pip/wheels/8d/be/39/442d457ebac7588268d35a4b9665bfa5037d90071406e6a6d5
#   Building wheel for ncls (setup.py) ... done
#   Created wheel for ncls: filename=ncls-0.0.53-cp36-cp36m-linux_x86_64.whl size=1760231 sha256=0819d0a428ef40827de60d98bda130db0d427f130ba784d95bafcfd6178703eb
#   Stored in directory: /root/.cache/pip/wheels/a4/6c/6a/c4a691a4897d832722692ccdd455cc02e1e4a196278062af45
#   Building wheel for sorted-nearest (setup.py) ... done
#   Created wheel for sorted-nearest: filename=sorted_nearest-0.0.31-cp36-cp36m-linux_x86_64.whl size=4106122 sha256=ad0542813fde73b468b3cc7ffce2e6d03d58660f853658b967cefc56fc57d59b
#   Stored in directory: /root/.cache/pip/wheels/e4/e3/91/b6606a13057e9c49c30aba06a2aa1553e74e5e473d9c4d0c1c
#   Building wheel for pyrle (setup.py) ... done
#   Created wheel for pyrle: filename=pyrle-0.0.31-cp36-cp36m-linux_x86_64.whl size=1239870 sha256=10328938c31d776fe6e79d6dfb48c40f7627d2995a606f593640ed36a6b9c4ac
#   Stored in directory: /root/.cache/pip/wheels/8e/31/f1/0c4fb6f657c3f577d09913c374bef1ad3f24276d4acaef9d8a
# Successfully built pyranges ncls sorted-nearest pyrle
# Installing collected packages: ncls, sorted-nearest, pyrle, pyranges
# Successfully installed ncls-0.0.53 pyranges-0.0.79 pyrle-0.0.31 sorted-nearest-0.0.31

# %%
import pandas as pd
import pyranges as pr
cgi = pr.read_bed("CGI.bed", as_df=True)
cgi = cgi.loc[cgi['Chromosome'] == 'chr15']
cgi.to_csv('chr15_cgi.csv', index = False)
chr15_cgi = pd.read_csv('chr15_cgi.csv')
chr15_cgi
# Out:
#     Chromosome      Start        End  Name
# 0        chr15   19898886   19899448    55
# 1        chr15   19943439   19944862   170
# 2        chr15   20074170   20074472    32
# 3        chr15   20168340   20168830    47
# 4        chr15   20294621   20295605   100
# ..         ...        ...        ...   ...
# 776      chr15  101651961  101653142   120
# 777      chr15  101723986  101724547    75
# 778      chr15  101745482  101746213    84
# 779      chr15  101752507  101764820   798
# 780      chr15  101961150  101962226   116
#
# [781 rows x 4 columns]

# %%
import pandas as pd
df = pd.read_csv('out.csv')
chr15_cgi = pd.read_csv('chr15_cgi.csv')
df['Loc_to_CGI'] = ""
for i in range(0, len(chr15_cgi)):
  df.loc[(df['start position'] >= chr15_cgi.iloc[i][1]) & (df['end position'] <= chr15_cgi.iloc[i][2]), 'Loc_to_CGI'] = 1
df.loc[df['Loc_to_CGI'] == '' , 'Loc_to_CGI'] = 0
df1 = df
df1.to_csv('Loc_to_CGI.csv')
Loc_to_CGI = pd.read_csv('Loc_to_CGI.csv')
Loc_to_CGI
# Out:
#         Unnamed: 0  ...  Loc_to_CGI
# 0                0  ...           0
# 1                1  ...           0
# 2                2  ...           0
# 3                3  ...           0
# 4                4  ...           0
# ...            ...  ...         ...
# 897759      897759  ...           0
# 897760      897760  ...           0
# 897761      897761  ...           0
# 897762      897762  ...           0
# 897763      897763  ...           0
#
# [897764 rows x 8 columns]

# %%
Loc_to_CGI1 = Loc_to_CGI.loc[Loc_to_CGI['Loc_to_CGI'] == 1]
Loc_to_CGI1 = Loc_to_CGI1.reset_index()
Loc_to_CGI1
# Out:
#         index  Unnamed: 0  ...  fraction of reads have dna methylation  Loc to CGI
# 0       32688       32688  ...                                0.894737           1
# 1       32689       32689  ...                                0.965517           1
# 2       32690       32690  ...                                0.946429           1
# 3       32691       32691  ...                                0.883333           1
# 4       32692       32692  ...                                0.900000           1
# ...       ...         ...  ...                                     ...         ...
# 19413  292481      292481  ...                                0.000000           1
# 19414  292482      292482  ...                                0.000000           1
# 19415  292483      292483  ...                                0.000000           1
# 19416  292484      292484  ...                                0.047619           1
# 19417  292485      292485  ...                                0.000000           1
#
# [19418 rows x 7 columns]
