# %%
import pandas as pd 
# Making data frame from the csv file 
df1 = pd.read_csv("out.csv")#dataset loding
# df2=pd.read_csv("ot.csv")

# %% [markdown]
# **#Dataset loding**

# %%
import numpy as np
import scipy
import matplotlib.pyplot as plt
from pylab import rcParams
import sklearn
import urllib
from sklearn.neighbors import KNeighborsRegressor
from sklearn import neighbors
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn import metrics

# %%
df1[:5]
# Out:
#    chromosome number  ...  fraction of reads have dna methylation
# 0                 15  ...                                     NaN
# 1                 15  ...                                0.416667
# 2                 15  ...                                0.914286
# 3                 15  ...                                0.670732
# 4                 15  ...                                0.978495
#
# [5 rows x 6 columns]

# %% [markdown]
# **Replace NaN to ) value**

# %%
df = df1.replace(np.nan, 0, regex=True)

# %%
df[:5]
# Out:
#    chromosome number  ...  fraction of reads have dna methylation
# 0                 15  ...                                0.000000
# 1                 15  ...                                0.416667
# 2                 15  ...                                0.914286
# 3                 15  ...                                0.670732
# 4                 15  ...                                0.978495
#
# [5 rows x 6 columns]

# %%
np.set_printoptions(precision=4,suppress=True)
# %matplotlib inline
rcParams['figure.figsize']=7,4
plt.style.use('seaborn-whitegrid')
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# **Dependent and independent variable declairing**

# %%
X_prime = df.iloc[:,[1,2]].values
y = df.iloc[:,5].values

# %% [markdown]
# **Train and Test set seperation**

# %%
X_train,X_test,y_train,y_test=train_test_split(X_prime,y,test_size=.33,random_state=17)

# %% [markdown]
# **Model Fit**

# %%
clf=neighbors.KNeighborsRegressor(n_neighbors=2)
clf.fit(X_train,y_train)
# Out:
# KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#                     metric_params=None, n_jobs=None, n_neighbors=2, p=2,
#                     weights='uniform')

# %% [markdown]
# **Show X test**

# %%
X_test
# Out:
# array([[86450564, 86450566],
#        [73301748, 73301750],
#        [42437884, 42437886],
#        ...,
#        [88779499, 88779501],
#        [31205156, 31205158],
#        [82748825, 82748827]])

# %%
# X_prime=df2.iloc[:,[1,2]].values

# %%
# test=X_prime.tolist()

# %%
# k=test.int

# %%
#Here show 1st one prediction and test value

print(X_test[0])
y_pred1=clf.predict([[17000043, 17000045]])
y_pred1
# Out:
# [86450564 86450566]
# array([0.2083])

# %% [markdown]
# **Predict all test by model**

# %%
print(X_test)
y_pred=clf.predict(X_test)
# Out:
# [[86450564 86450566]
#  [73301748 73301750]
#  [42437884 42437886]
#  ...
#  [88779499 88779501]
#  [31205156 31205158]
#  [82748825 82748827]]

# %%
#print predict

y_pred
# Out:
# array([0.4194, 0.9555, 0.9778, ..., 0.9459, 0.796 , 0.6573])

# %%
# Calculate the Mean Absolute Error, Mean Squared Error, and the Root Mean Squared Error.



from sklearn import metrics

print('MAE:', metrics.mean_absolute_error(y_test,y_pred))
print('MSE:', metrics.mean_squared_error(y_test,y_pred))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test,y_pred)))
# Out:
# MAE: 0.13971835407443725
# MSE: 0.04679788062937981
# RMSE: 0.21632817807530255

# %%
# Plot a histogram of the residuals and make sure it looks normally distributed. Use either seaborn distplot, or just plt.hist().



import seaborn as sns
sns.distplot((y_pred),bins=100,color="r", label="Predicted")
sns.distplot((y_test),bins=100,color="b", label="Real")
plt.title("Real vs Predict data")
plt.legend()

# %%
plt.hist([y_test,y_pred],rwidth=.5, color=['green','orange'],label=['Real','Predict'])
plt.title("Real vs Predict data")
plt.legend()

# %%
#Visualize the correlation by creating a heat map.



import seaborn as sns
plt.figure(figsize=(5,5))  
sns.heatmap(df.corr(), annot=True, fmt='.0%')
plt.title("Correlation")
# Out:
# Text(0.5, 1, 'Correlation')

# %%
# print the R-squared value for the model
clf.score(X_train,y_train)
# Out:
# 0.8719091464206647

# %%
from sklearn.metrics import confusion_matrix 
from sklearn.metrics import accuracy_score

# %%
results = confusion_matrix(y_test, y_pred)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-49-d443e9cf2292> in <module>()
# ----> 1 results = confusion_matrix(y_test, y_pred)
#
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py in confusion_matrix(y_true, y_pred, labels, sample_weight, normalize)
#     266
#     267     """
# --> 268     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     269     if y_type not in ("binary", "multiclass"):
#     270         raise ValueError("%s is not supported" % y_type)
#
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py in _check_targets(y_true, y_pred)
#      95     # No metrics support "multiclass-multioutput" format
#      96     if (y_type not in ["binary", "multiclass", "multilabel-indicator"]):
# ---> 97         raise ValueError("{0} is not supported".format(y_type))
#      98
#      99     if y_type in ["binary", "multiclass"]:
#
# ValueError: continuous is not supported

# %%
print 'Confusion Matrix :'
print(results)
# Out:
#   File "<ipython-input-50-5249da60cd92>", line 1
#     print 'Confusion Matrix :'
#                              ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print('Confusion Matrix :')?
